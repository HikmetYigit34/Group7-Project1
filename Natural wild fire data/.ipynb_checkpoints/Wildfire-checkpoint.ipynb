# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
file_path = "wildfire.csv"
df = pd.read_csv(file_path)

# %%
wildfire_df = pd.DataFrame(df)
wildfire_df
# Out:
#          YEAR  NFIREID  BASRC  FIREMAPS  FIREMAPM  FIRECAUS  BURNCLAS SDATE  \
# 0      1986.0    208.0    1.0       9.0       7.0       2.0       4.0   NaN
# 1      1986.0     31.0    1.0       9.0       7.0       4.0       4.0   NaN
# 2      1986.0    159.0    3.0       0.0       2.0       4.0       4.0   NaN
# 3      1986.0    102.0    3.0       0.0       2.0       4.0       4.0   NaN
# 4      1986.0     13.0    1.0       9.0       7.0       2.0       4.0   NaN
# ...       ...      ...    ...       ...       ...       ...       ...   ...
# 36912  2021.0   2760.0    3.0       0.0       0.0       3.0       4.0   NaN
# 36913  2021.0   2884.0    3.0       0.0       5.0       2.0       4.0   NaN
# 36914  2021.0   2891.0    3.0       0.0       0.0       4.0       4.0   NaN
# 36915  2021.0   2861.0    3.0       0.0       5.0       4.0       4.0   NaN
# 36916  2021.0   2569.0    3.0       2.0       3.0       4.0       4.0   NaN
#
# ...
